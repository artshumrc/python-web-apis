# %% [markdown]
# # Working with APIs in Python
#
# Making API requests in Python can be really simple. There's a low-level module called urllib that can also make the kinds of web requests that we want, but it's not as friendly as the `requests` module, which we'll be using.

# %%
import requests

# %% [markdown]
# ## Authentication
#
# You'll have to authenticate each request to Geonames with your username. Other APIs may require a key or token of some kind, but GeoNames has some very simple authentication, which makes things easy for us. You can sign up for a username [here](http://www.geonames.org/login).

# %%
USERNAME = 'cdc43339' # Enter your own username here

# %% [markdown]
# ## Query Parameters
#
# We're going to be using the same base URL for all of our requests, but we're also going to want to use several different query parameters to search through the GeoNames database. We have a full list of available parameters [here](), but for now we're going to set up the simplest keyword search, using a Python dictionary to contain our parameter / value pairs.

# %%
url = "http://api.geonames.org/searchJSON"
Q = {
    'q':'Cambridge',
    'username':USERNAME
}

# %% [markdown]
# ### Refresher on Dictionaries
#
# Python dictionaries are sets of key / value pairs, where a value can be accessed by its key. You're essentially naming a value in a container, so you can easily call it up later.
#
# Dictionaries have very fast lookups, so you can get a value from its key very quickly, no matter how large the dictionary is. However, they are also unordered, so if you iterate through all of the key / value pairs in the dictionary, there's no guarantee that they'll be in the same order.
#
# We're just going to be looking up data in dictionaries, so here's a quick refresher on the syntax:

# %%
Q['q']
# Out:
# 'Cambridge'

# %%
Q['username'] # This also works when we've set the value to another variable
# Out:
# 'cdc43339'

# %%
Q['q'] = 'Somerville' # You can also set the value of a key like you would a variable

# %% [markdown]
# ## Making a Request
#
# We have a base url, and we have our query parameters in a dictionary, so now we can make our request, like so:

# %%
R = requests.get(url,params=Q)

# %% [markdown]
# ### Formatted parameters
#
# That request has created a request object, which contains not only the data that we get from GeoNames, but information on the request we sent, like the URL that it used. Notice that requests has turned our query parameter dictionary into a GET request at the end of our URL.
#
# If you've been working with API requests or web scraping before, you might be used to seeing URLs get constructed like this:
#
# ```python
# url = "http://api.geonames.org/searchJSON?q=" + query + "&username=" + username
# ```
#
# If you have, I'm sure you'll appreciate how much simpler this is, especially when dealing with more query parameters.

# %%
R.url
# Out:
# 'http://api.geonames.org/searchJSON?q=Somerville&username=cdc43339'

# %% [markdown]
# ### Taking a look at the results
#
# Request objects have a built-in method, `.json()`, which converts a JSON file received as a response to a request from a string of text that happens to be in this data format into Python native data structures, like lists, dictionaries, numbers and strings. We can use this method to see a pretty friendly view of what we've gotten as a response to our request.

# %%
R.json()
# Out:
# {'geonames': [{'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4951257,
#    'lat': '42.3876',
#    'lng': '-71.0995',
#    'name': 'Somerville',
#    'population': 80318,
#    'toponymName': 'Somerville'},
#   {'adminName1': '',
#    'countryCode': 'AQ',
#    'countryId': '6697173',
#    'countryName': 'Antarctica',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'ISL',
#    'fcodeName': 'island',
#    'geonameId': 6625691,
#    'lat': '-65.37611',
#    'lng': '-64.30702',
#    'name': 'Somerville Island',
#    'population': 0,
#    'toponymName': 'Somerville, islote'},
#   {'adminCode1': '07',
#    'adminCodes1': {'ISO3166_2': 'VIC'},
#    'adminName1': 'Victoria',
#    'countryCode': 'AU',
#    'countryId': '2077456',
#    'countryName': 'Australia',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPLX',
#    'fcodeName': 'section of populated place',
#    'geonameId': 2149128,
#    'lat': '-38.21667',
#    'lng': '145.16667',
#    'name': 'Somerville',
#    'population': 7015,
#    'toponymName': 'Somerville'},
#   {'adminCode1': '02',
#    'adminCodes1': {'ISO3166_2': 'NSW'},
#    'adminName1': 'New South Wales',
#    'countryCode': 'AU',
#    'countryId': '2077456',
#    'countryName': 'Australia',
#    'fcl': 'L',
#    'fclName': 'parks,area, ...',
#    'fcode': 'PRK',
#    'fcodeName': 'park',
#    'geonameId': 8160913,
#    'lat': '-33.7818',
#    'lng': '151.0846',
#    'name': 'Somerville Park',
#    'population': 0,
#    'toponymName': 'Somerville Park'},
#   {'adminCode1': '08',
#    'adminCodes1': {'ISO3166_2': 'WA'},
#    'adminName1': 'Western Australia',
#    'countryCode': 'AU',
#    'countryId': '2077456',
#    'countryName': 'Australia',
#    'fcl': 'L',
#    'fclName': 'parks,area, ...',
#    'fcode': 'PRK',
#    'fcodeName': 'park',
#    'geonameId': 8857322,
#    'lat': '-32.05889',
#    'lng': '115.835',
#    'name': 'Somerville Park',
#    'population': 0,
#    'toponymName': 'Somerville Park'},
#   {'adminCode1': '00',
#    'adminName1': '',
#    'countryCode': 'SB',
#    'countryId': '2103350',
#    'countryName': 'Solomon Islands',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'PT',
#    'fcodeName': 'point',
#    'geonameId': 2103344,
#    'lat': '-8.69267',
#    'lng': '157.5469',
#    'name': 'Somerville Point',
#    'population': 0,
#    'toponymName': 'Somerville Point'},
#   {'adminCode1': 'NJ',
#    'adminCodes1': {'ISO3166_2': 'NJ'},
#    'adminName1': 'New Jersey',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPLA2',
#    'fcodeName': 'seat of a second-order administrative division',
#    'geonameId': 5104774,
#    'lat': '40.57427',
#    'lng': '-74.60988',
#    'name': 'Somerville',
#    'population': 12202,
#    'toponymName': 'Somerville'},
#   {'adminCode1': '08',
#    'adminCodes1': {'ISO3166_2': 'ON'},
#    'adminName1': 'Ontario',
#    'countryCode': 'CA',
#    'countryId': '6251999',
#    'countryName': 'Canada',
#    'fcl': 'L',
#    'fclName': 'parks,area, ...',
#    'fcode': 'AREA',
#    'fcodeName': 'area',
#    'geonameId': 6151206,
#    'lat': '44.70012',
#    'lng': '-78.71627',
#    'name': 'Somerville',
#    'population': 0,
#    'toponymName': 'Somerville'},
#   {'adminCode1': '10',
#    'adminCodes1': {'ISO3166_2': 'QC'},
#    'adminName1': 'Quebec',
#    'countryCode': 'CA',
#    'countryId': '6251999',
#    'countryName': 'Canada',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'PT',
#    'fcodeName': 'point',
#    'geonameId': 6108496,
#    'lat': '46.91683',
#    'lng': '-78.96631',
#    'name': 'Pointe Somerville',
#    'population': 0,
#    'toponymName': 'Pointe Somerville'},
#   {'adminCode1': 'TX',
#    'adminCodes1': {'ISO3166_2': 'TX'},
#    'adminName1': 'Texas',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4732809,
#    'lat': '30.34604',
#    'lng': '-96.5283',
#    'name': 'Somerville',
#    'population': 1383,
#    'toponymName': 'Somerville'},
#   {'adminCode1': 'ME',
#    'adminCodes1': {'ISO3166_2': 'ME'},
#    'adminName1': 'Maine',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4978976,
#    'lat': '44.30924',
#    'lng': '-69.48893',
#    'name': 'Somerville',
#    'population': 529,
#    'toponymName': 'Somerville'},
#   {'adminCode1': 'IN',
#    'adminCodes1': {'ISO3166_2': 'IN'},
#    'adminName1': 'Indiana',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4265011,
#    'lat': '38.27644',
#    'lng': '-87.37779',
#    'name': 'Somerville',
#    'population': 288,
#    'toponymName': 'Somerville'},
#   {'adminCode1': 'TN',
#    'adminCodes1': {'ISO3166_2': 'TN'},
#    'adminName1': 'Tennessee',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPLA2',
#    'fcodeName': 'seat of a second-order administrative division',
#    'geonameId': 4658802,
#    'lat': '35.2437',
#    'lng': '-89.35007',
#    'name': 'Somerville',
#    'population': 3094,
#    'toponymName': 'Somerville'},
#   {'adminCode1': 'OH',
#    'adminCodes1': {'ISO3166_2': 'OH'},
#    'adminName1': 'Ohio',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4525006,
#    'lat': '39.56311',
#    'lng': '-84.63856',
#    'name': 'Somerville',
#    'population': 286,
#    'toponymName': 'Somerville'},
#   {'adminCode1': 'ME',
#    'adminCodes1': {'ISO3166_2': 'ME'},
#    'adminName1': 'Maine',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'A',
#    'fclName': 'country, state, region,...',
#    'fcode': 'ADM3',
#    'fcodeName': 'third-order administrative division',
#    'geonameId': 4978978,
#    'lat': '44.28956',
#    'lng': '-69.47771',
#    'name': 'Town of Somerville',
#    'population': 553,
#    'toponymName': 'Town of Somerville'},
#   {'adminCode1': '10',
#    'adminCodes1': {'ISO3166_2': '14'},
#    'adminName1': 'Saint Catherine',
#    'countryCode': 'JM',
#    'countryId': '3489940',
#    'countryName': 'Jamaica',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 3488490,
#    'lat': '18.13333',
#    'lng': '-77.05',
#    'name': 'Somerville',
#    'population': 0,
#    'toponymName': 'Somerville'},
#   {'adminCode1': '08',
#    'adminCodes1': {'ISO3166_2': 'ON'},
#    'adminName1': 'Ontario',
#    'countryCode': 'CA',
#    'countryId': '6251999',
#    'countryName': 'Canada',
#    'fcl': 'H',
#    'fclName': 'stream, lake, ...',
#    'fcode': 'LK',
#    'fcodeName': 'lake',
#    'geonameId': 6151214,
#    'lat': '49.8543',
#    'lng': '-95.04728',
#    'name': 'Somerville Lake',
#    'population': 0,
#    'toponymName': 'Somerville Lake'},
#   {'adminCode1': '03',
#    'adminCodes1': {'ISO3166_2': 'MB'},
#    'adminName1': 'Manitoba',
#    'countryCode': 'CA',
#    'countryId': '6251999',
#    'countryName': 'Canada',
#    'fcl': 'H',
#    'fclName': 'stream, lake, ...',
#    'fcode': 'LK',
#    'fcodeName': 'lake',
#    'geonameId': 6151215,
#    'lat': '58.3414',
#    'lng': '-101.69326',
#    'name': 'Somerville Lake',
#    'population': 0,
#    'toponymName': 'Somerville Lake'},
#   {'adminCode1': '11',
#    'adminCodes1': {'ISO3166_2': 'SK'},
#    'adminName1': 'Saskatchewan',
#    'countryCode': 'CA',
#    'countryId': '6251999',
#    'countryName': 'Canada',
#    'fcl': 'H',
#    'fclName': 'stream, lake, ...',
#    'fcode': 'LK',
#    'fcodeName': 'lake',
#    'geonameId': 6151216,
#    'lat': '59.50018',
#    'lng': '-105.05065',
#    'name': 'Somerville Lake',
#    'population': 0,
#    'toponymName': 'Somerville Lake'},
#   {'adminCode1': '10',
#    'adminCodes1': {'ISO3166_2': 'QC'},
#    'adminName1': 'Quebec',
#    'countryCode': 'CA',
#    'countryId': '6251999',
#    'countryName': 'Canada',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 6106079,
#    'lat': '45.08754',
#    'lng': '-74.4249',
#    'name': 'Plage-Somerville',
#    'population': 0,
#    'toponymName': 'Plage-Somerville'},
#   {'adminCode1': 'AL',
#    'adminCodes1': {'ISO3166_2': 'AL'},
#    'adminName1': 'Alabama',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4090853,
#    'lat': '34.47338',
#    'lng': '-86.7987',
#    'name': 'Somerville',
#    'population': 716,
#    'toponymName': 'Somerville'},
#   {'adminCode1': 'VA',
#    'adminCodes1': {'ISO3166_2': 'VA'},
#    'adminName1': 'Virginia',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4786488,
#    'lat': '38.52179',
#    'lng': '-77.60943',
#    'name': 'Somerville',
#    'population': 0,
#    'toponymName': 'Somerville'},
#   {'adminCode1': '08',
#    'adminCodes1': {'ISO3166_2': 'WA'},
#    'adminName1': 'Western Australia',
#    'countryCode': 'AU',
#    'countryId': '2077456',
#    'countryName': 'Australia',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'ISL',
#    'fcodeName': 'island',
#    'geonameId': 2079488,
#    'lat': '-21.96434',
#    'lng': '114.4868',
#    'name': 'Somerville Island',
#    'population': 0,
#    'toponymName': 'Somerville Island'},
#   {'adminCode1': 'TX',
#    'adminCodes1': {'ISO3166_2': 'TX'},
#    'adminName1': 'Texas',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'A',
#    'fclName': 'country, state, region,...',
#    'fcode': 'ADM3',
#    'fcodeName': 'third-order administrative division',
#    'geonameId': 7174466,
#    'lat': '30.346',
#    'lng': '-96.53109',
#    'name': 'City of Somerville',
#    'population': 1376,
#    'toponymName': 'City of Somerville'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'A',
#    'fclName': 'country, state, region,...',
#    'fcode': 'ADM3',
#    'fcodeName': 'third-order administrative division',
#    'geonameId': 4951267,
#    'lat': '42.39072',
#    'lng': '-71.10131',
#    'name': 'City of Somerville',
#    'population': 75754,
#    'toponymName': 'City of Somerville'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4955085,
#    'lat': '42.39593',
#    'lng': '-71.12255',
#    'name': 'West Somerville',
#    'population': 0,
#    'toponymName': 'West Somerville'},
#   {'adminCode1': 'IN',
#    'adminCodes1': {'ISO3166_2': 'IN'},
#    'adminName1': 'Indiana',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'A',
#    'fclName': 'country, state, region,...',
#    'fcode': 'ADMD',
#    'fcodeName': 'administrative division',
#    'geonameId': 7165421,
#    'lat': '38.27838',
#    'lng': '-87.37736',
#    'name': 'Town of Somerville',
#    'population': 293,
#    'toponymName': 'Town of Somerville'},
#   {'adminCode1': 'OH',
#    'adminCodes1': {'ISO3166_2': 'OH'},
#    'adminName1': 'Ohio',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'A',
#    'fclName': 'country, state, region,...',
#    'fcode': 'ADMD',
#    'fcodeName': 'administrative division',
#    'geonameId': 7167457,
#    'lat': '39.56353',
#    'lng': '-84.63956',
#    'name': 'Village of Somerville',
#    'population': 281,
#    'toponymName': 'Village of Somerville'},
#   {'adminCode1': 'AL',
#    'adminCodes1': {'ISO3166_2': 'AL'},
#    'adminName1': 'Alabama',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'A',
#    'fclName': 'country, state, region,...',
#    'fcode': 'ADMD',
#    'fcodeName': 'administrative division',
#    'geonameId': 7172575,
#    'lat': '34.46512',
#    'lng': '-86.7875',
#    'name': 'Town of Somerville',
#    'population': 724,
#    'toponymName': 'Town of Somerville'},
#   {'adminCode1': 'TN',
#    'adminCodes1': {'ISO3166_2': 'TN'},
#    'adminName1': 'Tennessee',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'A',
#    'fclName': 'country, state, region,...',
#    'fcode': 'ADMD',
#    'fcodeName': 'administrative division',
#    'geonameId': 7172576,
#    'lat': '35.23403',
#    'lng': '-89.38035',
#    'name': 'Town of Somerville',
#    'population': 3094,
#    'toponymName': 'Town of Somerville'},
#   {'adminCode1': '14',
#    'adminCodes1': {'ISO3166_2': 'NU'},
#    'adminName1': 'Nunavut',
#    'countryCode': 'CA',
#    'countryId': '6251999',
#    'countryName': 'Canada',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'ISL',
#    'fcodeName': 'island',
#    'geonameId': 6151213,
#    'lat': '74.73485',
#    'lng': '-96.18496',
#    'name': 'Somerville Island',
#    'population': 0,
#    'toponymName': 'Somerville Island'},
#   {'adminCode1': 'TX',
#    'adminCodes1': {'ISO3166_2': 'TX'},
#    'adminName1': 'Texas',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'L',
#    'fclName': 'parks,area, ...',
#    'fcode': 'PRK',
#    'fcodeName': 'park',
#    'geonameId': 4705073,
#    'lat': '30.31021',
#    'lng': '-96.62886',
#    'name': 'Lake Somerville State Park',
#    'population': 0,
#    'toponymName': 'Lake Somerville State Park'},
#   {'adminCode1': 'TX',
#    'adminCodes1': {'ISO3166_2': 'TX'},
#    'adminName1': 'Texas',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'L',
#    'fclName': 'parks,area, ...',
#    'fcode': 'PRK',
#    'fcodeName': 'park',
#    'geonameId': 4732813,
#    'lat': '30.33271',
#    'lng': '-96.75498',
#    'name': 'Somerville Wildlife Management Area',
#    'population': 0,
#    'toponymName': 'Somerville Wildlife Management Area'},
#   {'adminCode1': 'TX',
#    'adminCodes1': {'ISO3166_2': 'TX'},
#    'adminName1': 'Texas',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'H',
#    'fclName': 'stream, lake, ...',
#    'fcode': 'RSV',
#    'fcodeName': 'reservoir(s)',
#    'geonameId': 4732812,
#    'lat': '30.32549',
#    'lng': '-96.52747',
#    'name': 'Somerville Lake',
#    'population': 0,
#    'toponymName': 'Somerville Lake'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'SCH',
#    'fcodeName': 'school',
#    'geonameId': 4951262,
#    'lat': '42.38732',
#    'lng': '-71.09616',
#    'name': 'Somerville High School',
#    'population': 0,
#    'toponymName': 'Somerville High School'},
#   {'adminCode1': 'NJ',
#    'adminCodes1': {'ISO3166_2': 'NJ'},
#    'adminName1': 'New Jersey',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'A',
#    'fclName': 'country, state, region,...',
#    'fcode': 'ADM3',
#    'fcodeName': 'third-order administrative division',
#    'geonameId': 5104779,
#    'lat': '40.56962',
#    'lng': '-74.60928',
#    'name': 'Borough of Somerville',
#    'population': 12098,
#    'toponymName': 'Borough of Somerville'},
#   {'adminCode1': 'ENG',
#    'adminCodes1': {'ISO3166_2': 'ENG'},
#    'adminName1': 'England',
#    'countryCode': 'GB',
#    'countryId': '2635167',
#    'countryName': 'United Kingdom',
#    'fcl': 'A',
#    'fclName': 'country, state, region,...',
#    'fcode': 'ADM4',
#    'fcodeName': 'fourth-order administrative division',
#    'geonameId': 7297525,
#    'lat': '52.04147',
#    'lng': '-1.93328',
#    'name': 'Aston Somerville',
#    'population': 0,
#    'toponymName': 'Aston Somerville'},
#   {'adminCode1': 'WY',
#    'adminCodes1': {'ISO3166_2': 'WY'},
#    'adminName1': 'Wyoming',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'VAL',
#    'fcodeName': 'valley',
#    'geonameId': 5838920,
#    'lat': '44.26998',
#    'lng': '-106.12558',
#    'name': 'Somerville Draw',
#    'population': 0,
#    'toponymName': 'Somerville Draw'},
#   {'adminCode1': '08',
#    'adminCodes1': {'ISO3166_2': 'ON'},
#    'adminName1': 'Ontario',
#    'countryCode': 'CA',
#    'countryId': '6251999',
#    'countryName': 'Canada',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'ISL',
#    'fcodeName': 'island',
#    'geonameId': 6151210,
#    'lat': '46.1834',
#    'lng': '-79.54964',
#    'name': 'Somerville Island',
#    'population': 0,
#    'toponymName': 'Somerville Island'},
#   {'adminCode1': '03',
#    'adminCodes1': {'ISO3166_2': 'MB'},
#    'adminName1': 'Manitoba',
#    'countryCode': 'CA',
#    'countryId': '6251999',
#    'countryName': 'Canada',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'ISL',
#    'fcodeName': 'island',
#    'geonameId': 6151211,
#    'lat': '55.27205',
#    'lng': '-101.23325',
#    'name': 'Somerville Island',
#    'population': 0,
#    'toponymName': 'Somerville Island'},
#   {'adminCode1': '02',
#    'adminCodes1': {'ISO3166_2': 'BC'},
#    'adminName1': 'British Columbia',
#    'countryCode': 'CA',
#    'countryId': '6251999',
#    'countryName': 'Canada',
#    'fcl': 'H',
#    'fclName': 'stream, lake, ...',
#    'fcode': 'LK',
#    'fcodeName': 'lake',
#    'geonameId': 6151217,
#    'lat': '50.53111',
#    'lng': '-120.35167',
#    'name': 'Somerville Lake',
#    'population': 0,
#    'toponymName': 'Somerville Lake'},
#   {'adminCode1': 'MI',
#    'adminCodes1': {'ISO3166_2': 'MI'},
#    'adminName1': 'Michigan',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'AIRP',
#    'fcodeName': 'airport',
#    'geonameId': 5010336,
#    'lat': '42.94178',
#    'lng': '-85.48583',
#    'name': 'Somerville Airport',
#    'population': 0,
#    'toponymName': 'Somerville Airport'},
#   {'adminCode1': '08',
#    'adminCodes1': {'ISO3166_2': 'WA'},
#    'adminName1': 'Western Australia',
#    'countryCode': 'AU',
#    'countryId': '2077456',
#    'countryName': 'Australia',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPLX',
#    'fcodeName': 'section of populated place',
#    'geonameId': 8349422,
#    'lat': '-30.76979',
#    'lng': '121.45438',
#    'name': 'Somerville',
#    'population': 0,
#    'toponymName': 'Somerville'},
#   {'adminCode1': 'AL',
#    'adminCodes1': {'ISO3166_2': 'AL'},
#    'adminName1': 'Alabama',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'BLDG',
#    'fcodeName': 'building(s)',
#    'geonameId': 11524086,
#    'lat': '34.47289',
#    'lng': '-86.79838',
#    'name': 'Somerville Courthouse (historical)',
#    'population': 0,
#    'toponymName': 'Somerville Courthouse (historical)'},
#   {'adminCode1': 'L',
#    'adminCodes1': {'ISO3166_2': 'L'},
#    'adminName1': 'Leinster',
#    'countryCode': 'IE',
#    'countryId': '2963597',
#    'countryName': 'Ireland',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'EST',
#    'fcodeName': 'estate(s)',
#    'geonameId': 2961404,
#    'lat': '53.63139',
#    'lng': '-6.51167',
#    'name': 'Somerville House',
#    'population': 0,
#    'toponymName': 'Somerville House'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4935509,
#    'lat': '42.38673',
#    'lng': '-71.0839',
#    'name': 'East Somerville',
#    'population': 0,
#    'toponymName': 'East Somerville'},
#   {'adminCode1': 'NJ',
#    'adminCodes1': {'ISO3166_2': 'NJ'},
#    'adminName1': 'New Jersey',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'SCH',
#    'fcodeName': 'school',
#    'geonameId': 5104777,
#    'lat': '40.57816',
#    'lng': '-74.6121',
#    'name': 'Somerville High School',
#    'population': 0,
#    'toponymName': 'Somerville High School'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'SCH',
#    'fcodeName': 'school',
#    'geonameId': 4953407,
#    'lat': '42.40454',
#    'lng': '-71.11978',
#    'name': 'Tufts University',
#    'population': 0,
#    'toponymName': 'Tufts University'},
#   {'adminName1': '',
#    'countryCode': 'JE',
#    'countryId': '3042142',
#    'countryName': 'Jersey',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'HTL',
#    'fcodeName': 'hotel',
#    'geonameId': 7117966,
#    'lat': '49.18532',
#    'lng': '-2.17063',
#    'name': 'somerville',
#    'population': 0,
#    'toponymName': 'somerville'},
#   {'adminCode1': 'MS',
#    'adminCodes1': {'ISO3166_2': 'MS'},
#    'adminName1': 'Mississippi',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4446529,
#    'lat': '33.79206',
#    'lng': '-90.26564',
#    'name': 'Somerville',
#    'population': 0,
#    'toponymName': 'Somerville'},
#   {'adminCode1': 'CT',
#    'adminCodes1': {'ISO3166_2': 'CT'},
#    'adminName1': 'Connecticut',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4843222,
#    'lat': '41.98287',
#    'lng': '-72.48786',
#    'name': 'Somersville',
#    'population': 0,
#    'toponymName': 'Somersville'},
#   {'adminCode1': 'OH',
#    'adminCodes1': {'ISO3166_2': 'OH'},
#    'adminName1': 'Ohio',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 5173379,
#    'lat': '40.40006',
#    'lng': '-83.41103',
#    'name': 'Summersville',
#    'population': 0,
#    'toponymName': 'Summersville'},
#   {'adminCode1': 'WY',
#    'adminCodes1': {'ISO3166_2': 'WY'},
#    'adminName1': 'Wyoming',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'PLN',
#    'fcodeName': 'plain(s)',
#    'geonameId': 5838924,
#    'lat': '44.26776',
#    'lng': '-106.11919',
#    'name': 'Somerville Flats',
#    'population': 0,
#    'toponymName': 'Somerville Flats'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'SCH',
#    'fcodeName': 'school',
#    'geonameId': 7143129,
#    'lat': '42.3788',
#    'lng': '-71.0965',
#    'name': 'Prospect Hill Academy Charter School',
#    'population': 0,
#    'toponymName': 'Prospect Hill Academy Charter School'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'HSP',
#    'fcodeName': 'hospital',
#    'geonameId': 7143328,
#    'lat': '42.3901',
#    'lng': '-71.1094',
#    'name': 'Cambridge Health Alliance-Somerville Hospital',
#    'population': 0,
#    'toponymName': 'Cambridge Health Alliance-Somerville Hospital'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'SQR',
#    'fcodeName': 'square',
#    'geonameId': 4934583,
#    'lat': '42.39593',
#    'lng': '-71.12116',
#    'name': 'Davis Square',
#    'population': 0,
#    'toponymName': 'Davis Square'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'HSP',
#    'fcodeName': 'hospital',
#    'geonameId': 4951264,
#    'lat': '42.39011',
#    'lng': '-71.1094',
#    'name': 'Cambridge Health Alliance Somerville Campus',
#    'population': 0,
#    'toponymName': 'Cambridge Health Alliance Somerville Campus'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4952743,
#    'lat': '42.39676',
#    'lng': '-71.087',
#    'name': 'Ten Hills',
#    'population': 0,
#    'toponymName': 'Ten Hills'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'SQR',
#    'fcodeName': 'square',
#    'geonameId': 4953625,
#    'lat': '42.37954',
#    'lng': '-71.09616',
#    'name': 'Union Square',
#    'population': 0,
#    'toponymName': 'Union Square'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'DAM',
#    'fcodeName': 'dam',
#    'geonameId': 4928966,
#    'lat': '42.3949',
#    'lng': '-71.07518',
#    'name': 'Amelia Earhart Dam',
#    'population': 0,
#    'toponymName': 'Amelia Earhart Dam'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'MALL',
#    'fcodeName': 'mall',
#    'geonameId': 4929348,
#    'lat': '42.39537',
#    'lng': '-71.08339',
#    'name': 'Assembly Square Mall Shopping Center',
#    'population': 0,
#    'toponymName': 'Assembly Square Mall Shopping Center'},
#   {'adminCode1': '04',
#    'adminCodes1': {'ISO3166_2': 'QLD'},
#    'adminName1': 'Queensland',
#    'countryCode': 'AU',
#    'countryId': '2077456',
#    'countryName': 'Australia',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'HMSD',
#    'fcodeName': 'homestead',
#    'geonameId': 2149130,
#    'lat': '-20.18333',
#    'lng': '142.71668',
#    'name': 'Somerville',
#    'population': 0,
#    'toponymName': 'Somerville'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'PO',
#    'fcodeName': 'post office',
#    'geonameId': 4951265,
#    'lat': '42.3801',
#    'lng': '-71.09366',
#    'name': 'Somerville Post Office',
#    'population': 0,
#    'toponymName': 'Somerville Post Office'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'SCH',
#    'fcodeName': 'school',
#    'geonameId': 4955087,
#    'lat': '42.40621',
#    'lng': '-71.12589',
#    'name': 'West Somerville Neighborhood School',
#    'population': 0,
#    'toponymName': 'West Somerville Neighborhood School'},
#   {'adminCode1': 'ME',
#    'adminCodes1': {'ISO3166_2': 'ME'},
#    'adminName1': 'Maine',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4968472,
#    'lat': '44.26091',
#    'lng': '-69.46004',
#    'name': 'Jones Corner',
#    'population': 0,
#    'toponymName': 'Jones Corner'},
#   {'adminCode1': 'ME',
#    'adminCodes1': {'ISO3166_2': 'ME'},
#    'adminName1': 'Maine',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4977709,
#    'lat': '44.30979',
#    'lng': '-69.4581',
#    'name': 'Sandhill Corner',
#    'population': 0,
#    'toponymName': 'Sandhill Corner'},
#   {'adminCode1': 'ME',
#    'adminCodes1': {'ISO3166_2': 'ME'},
#    'adminName1': 'Maine',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'MT',
#    'fcodeName': 'mountain',
#    'geonameId': 4961879,
#    'lat': '44.28868',
#    'lng': '-69.47865',
#    'name': 'Crummett Mountain',
#    'population': 0,
#    'toponymName': 'Crummett Mountain'},
#   {'adminCode1': 'ME',
#    'adminCodes1': {'ISO3166_2': 'ME'},
#    'adminName1': 'Maine',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'MT',
#    'fcodeName': 'mountain',
#    'geonameId': 4971251,
#    'lat': '44.32393',
#    'lng': '-69.44542',
#    'name': 'Marrs Hill',
#    'population': 0,
#    'toponymName': 'Marrs Hill'},
#   {'adminCode1': '02',
#    'adminCodes1': {'ISO3166_2': 'BC'},
#    'adminName1': 'British Columbia',
#    'countryCode': 'CA',
#    'countryId': '6251999',
#    'countryName': 'Canada',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'ISL',
#    'fcodeName': 'island',
#    'geonameId': 6151212,
#    'lat': '54.7387',
#    'lng': '-130.28',
#    'name': 'Somerville Island',
#    'population': 0,
#    'toponymName': 'Somerville Island'},
#   {'adminCode1': 'WV',
#    'adminCodes1': {'ISO3166_2': 'WV'},
#    'adminName1': 'West Virginia',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPLA2',
#    'fcodeName': 'seat of a second-order administrative division',
#    'geonameId': 4824027,
#    'lat': '38.28122',
#    'lng': '-80.8526',
#    'name': 'Summersville',
#    'population': 3478,
#    'toponymName': 'Summersville'},
#   {'adminCode1': 'PA',
#    'adminCodes1': {'ISO3166_2': 'PA'},
#    'adminName1': 'Pennsylvania',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 5212875,
#    'lat': '40.96062',
#    'lng': '-79.65394',
#    'name': 'Somerville',
#    'population': 0,
#    'toponymName': 'Somerville'},
#   {'adminCode1': 'PA',
#    'adminCodes1': {'ISO3166_2': 'PA'},
#    'adminName1': 'Pennsylvania',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 5212876,
#    'lat': '40.05178',
#    'lng': '-75.15129',
#    'name': 'Somerville',
#    'population': 0,
#    'toponymName': 'Somerville'},
#   {'adminCode1': '10',
#    'adminCodes1': {'ISO3166_2': 'QC'},
#    'adminName1': 'Quebec',
#    'countryCode': 'CA',
#    'countryId': '6251999',
#    'countryName': 'Canada',
#    'fcl': 'H',
#    'fclName': 'stream, lake, ...',
#    'fcode': 'BAY',
#    'fcodeName': 'bay',
#    'geonameId': 5890220,
#    'lat': '45.08589',
#    'lng': '-74.42955',
#    'name': 'Baie de Somerville',
#    'population': 0,
#    'toponymName': 'Baie de Somerville'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'BLDG',
#    'fcodeName': 'building(s)',
#    'geonameId': 7144275,
#    'lat': '42.39084',
#    'lng': '-71.09125',
#    'name': 'Somerville Fire Department Station 1 Headquarters',
#    'population': 0,
#    'toponymName': 'Somerville Fire Department Station 1 Headquarters'},
#   {'adminCode1': 'AL',
#    'adminCodes1': {'ISO3166_2': 'AL'},
#    'adminName1': 'Alabama',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'CH',
#    'fcodeName': 'church',
#    'geonameId': 4090855,
#    'lat': '34.43565',
#    'lng': '-86.82445',
#    'name': 'Somerville Church of God',
#    'population': 0,
#    'toponymName': 'Somerville Church of God'},
#   {'adminCode1': 'AL',
#    'adminCodes1': {'ISO3166_2': 'AL'},
#    'adminName1': 'Alabama',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'SCH',
#    'fcodeName': 'school',
#    'geonameId': 4090858,
#    'lat': '34.59343',
#    'lng': '-86.97167',
#    'name': 'Somerville Road Elementary School',
#    'population': 0,
#    'toponymName': 'Somerville Road Elementary School'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'BLDG',
#    'fcodeName': 'building(s)',
#    'geonameId': 4936408,
#    'lat': '42.39178',
#    'lng': '-71.1108',
#    'name': 'Somerville Fire Department Station 7',
#    'population': 0,
#    'toponymName': 'Somerville Fire Department Station 7'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'BLDG',
#    'fcodeName': 'building(s)',
#    'geonameId': 4936411,
#    'lat': '42.38466',
#    'lng': '-71.11133',
#    'name': 'Somerville Fire Department Station 4',
#    'population': 0,
#    'toponymName': 'Somerville Fire Department Station 4'},
#   {'adminCode1': 'TN',
#    'adminCodes1': {'ISO3166_2': 'TN'},
#    'adminName1': 'Tennessee',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'CMTY',
#    'fcodeName': 'cemetery',
#    'geonameId': 4658807,
#    'lat': '36.58282',
#    'lng': '-86.66583',
#    'name': 'Somerville Cemetery',
#    'population': 0,
#    'toponymName': 'Somerville Cemetery'},
#   {'adminCode1': 'NJ',
#    'adminCodes1': {'ISO3166_2': 'NJ'},
#    'adminName1': 'New Jersey',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'SCH',
#    'fcodeName': 'school',
#    'geonameId': 7157842,
#    'lat': '40.5806',
#    'lng': '-74.61785',
#    'name': 'Immaculata High School',
#    'population': 0,
#    'toponymName': 'Immaculata High School'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'MT',
#    'fcodeName': 'mountain',
#    'geonameId': 4932625,
#    'lat': '42.38787',
#    'lng': '-71.10894',
#    'name': 'Central Hall',
#    'population': 0,
#    'toponymName': 'Central Hall'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'MT',
#    'fcodeName': 'mountain',
#    'geonameId': 4933312,
#    'lat': '42.40482',
#    'lng': '-71.12728',
#    'name': 'Clarendon Hill',
#    'population': 0,
#    'toponymName': 'Clarendon Hill'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'MT',
#    'fcodeName': 'mountain',
#    'geonameId': 4947909,
#    'lat': '42.40037',
#    'lng': '-71.11644',
#    'name': 'Powder House Hill',
#    'population': 0,
#    'toponymName': 'Powder House Hill'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'MT',
#    'fcodeName': 'mountain',
#    'geonameId': 4948041,
#    'lat': '42.38176',
#    'lng': '-71.09339',
#    'name': 'Prospect Hill',
#    'population': 0,
#    'toponymName': 'Prospect Hill'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'MT',
#    'fcodeName': 'mountain',
#    'geonameId': 4951767,
#    'lat': '42.38843',
#    'lng': '-71.10922',
#    'name': 'Spring Hill',
#    'population': 0,
#    'toponymName': 'Spring Hill'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'MT',
#    'fcodeName': 'mountain',
#    'geonameId': 4955985,
#    'lat': '42.39537',
#    'lng': '-71.0995',
#    'name': 'Winter Hill',
#    'population': 0,
#    'toponymName': 'Winter Hill'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4955986,
#    'lat': '42.39593',
#    'lng': '-71.09894',
#    'name': 'Winter Hill',
#    'population': 0,
#    'toponymName': 'Winter Hill'},
#   {'adminCode1': 'NJ',
#    'adminCodes1': {'ISO3166_2': 'NJ'},
#    'adminName1': 'New Jersey',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'HSP',
#    'fcodeName': 'hospital',
#    'geonameId': 5104769,
#    'lat': '40.56863',
#    'lng': '-74.59595',
#    'name': 'Somerset Medical Center',
#    'population': 0,
#    'toponymName': 'Somerset Medical Center'},
#   {'adminCode1': 'NJ',
#    'adminCodes1': {'ISO3166_2': 'NJ'},
#    'adminName1': 'New Jersey',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'SCH',
#    'fcodeName': 'school',
#    'geonameId': 5099442,
#    'lat': '40.57312',
#    'lng': '-74.62037',
#    'name': 'Immaculate Conception School',
#    'population': 0,
#    'toponymName': 'Immaculate Conception School'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'T',
#    'fclName': 'mountain,hill,rock,... ',
#    'fcode': 'MT',
#    'fcodeName': 'mountain',
#    'geonameId': 4930328,
#    'lat': '42.3876',
#    'lng': '-71.08005',
#    'name': 'Mount Benedict',
#    'population': 0,
#    'toponymName': 'Mount Benedict'},
#   {'adminCode1': '02',
#    'adminCodes1': {'ISO3166_2': 'NSW'},
#    'adminName1': 'New South Wales',
#    'countryCode': 'AU',
#    'countryId': '2077456',
#    'countryName': 'Australia',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'FRM',
#    'fcodeName': 'farm',
#    'geonameId': 2149129,
#    'lat': '-35.8',
#    'lng': '146.35',
#    'name': 'Somerville',
#    'population': 0,
#    'toponymName': 'Somerville'},
#   {'adminCode1': '08',
#    'adminCodes1': {'ISO3166_2': 'NC'},
#    'adminName1': 'Northern Cape',
#    'countryCode': 'ZA',
#    'countryId': '953987',
#    'countryName': 'South Africa',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'FRM',
#    'fcodeName': 'farm',
#    'geonameId': 954142,
#    'lat': '-27.98333',
#    'lng': '22.11667',
#    'name': 'Somerville',
#    'population': 0,
#    'toponymName': 'Somerville'},
#   {'adminCode1': '10',
#    'adminCodes1': {'ISO3166_2': 'NW'},
#    'adminName1': 'North-West',
#    'countryCode': 'ZA',
#    'countryId': '953987',
#    'countryName': 'South Africa',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'FRM',
#    'fcodeName': 'farm',
#    'geonameId': 954143,
#    'lat': '-26.17412',
#    'lng': '27.22277',
#    'name': 'Somerville',
#    'population': 0,
#    'toponymName': 'Somerville'},
#   {'adminCode1': 'TX',
#    'adminCodes1': {'ISO3166_2': 'TX'},
#    'adminName1': 'Texas',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'R',
#    'fclName': 'road, railroad ',
#    'fcode': 'TRL',
#    'fcodeName': 'trail',
#    'geonameId': 4704830,
#    'lat': '30.30493',
#    'lng': '-96.63942',
#    'name': 'Lake Somerville Trailway',
#    'population': 0,
#    'toponymName': 'Lake Somerville Trailway'},
#   {'adminCode1': 'UT',
#    'adminCodes1': {'ISO3166_2': 'UT'},
#    'adminName1': 'Utah',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPLX',
#    'fcodeName': 'section of populated place',
#    'geonameId': 5781648,
#    'lat': '40.5205',
#    'lng': '-111.8566',
#    'name': 'Somerville in Draper',
#    'population': 0,
#    'toponymName': 'Somerville in Draper'},
#   {'adminCode1': 'NY',
#    'adminCodes1': {'ISO3166_2': 'NY'},
#    'adminName1': 'New York',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 5138687,
#    'lat': '44.28312',
#    'lng': '-75.55661',
#    'name': 'Somerville',
#    'population': 0,
#    'toponymName': 'Somerville'},
#   {'adminCode1': 'PA',
#    'adminCodes1': {'ISO3166_2': 'PA'},
#    'adminName1': 'Pennsylvania',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 5193711,
#    'lat': '40.60954',
#    'lng': '-75.59519',
#    'name': 'Hillside',
#    'population': 0,
#    'toponymName': 'Hillside'},
#   {'adminCode1': 'NY',
#    'adminCodes1': {'ISO3166_2': 'NY'},
#    'adminName1': 'New York',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 6332500,
#    'lat': '40.59556',
#    'lng': '-73.7975',
#    'name': 'Somerville',
#    'population': 0,
#    'toponymName': 'Somerville'},
#   {'adminCode1': 'NJ',
#    'adminCodes1': {'ISO3166_2': 'NJ'},
#    'adminName1': 'New Jersey',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'SCH',
#    'fcodeName': 'school',
#    'geonameId': 5104778,
#    'lat': '40.57208',
#    'lng': '-74.61376',
#    'name': 'Somerville Middle School',
#    'population': 0,
#    'toponymName': 'Somerville Middle School'},
#   {'adminCode1': '07',
#    'adminCodes1': {'ISO3166_2': 'VIC'},
#    'adminName1': 'Victoria',
#    'countryCode': 'AU',
#    'countryId': '2077456',
#    'countryName': 'Australia',
#    'fcl': 'S',
#    'fclName': 'spot, building, farm',
#    'fcode': 'RSTN',
#    'fcodeName': 'railroad station',
#    'geonameId': 8828816,
#    'lat': '-38.22542',
#    'lng': '145.17569',
#    'name': 'Somerville',
#    'population': 0,
#    'toponymName': 'Somerville'}],
#  'totalResultsCount': 332}

# %% [markdown]
# ## Changing our request
#
# Looking at the response, the Somerville in Massachusetts seems to be at the top of the pile. That's great for us, but sometimes you actually are looking for "Paris, TX" and not "Paris, France". In that case, you'll want to narrow your results. Let's try that with our request.
#
# We can specify the country we're talking about, and we can also specify the state abbreviation under "adminCode1", which is a general purpose place to put abbreviation for things like states and provinces. Finally, we can specify the kind of place that we want with "featureCode" set to "PPL" for "populated place", so we don't get various entries like schools and economic regions.
#
# All of these parameters are being drawn from the [GeoNames search API documentation](http://www.geonames.org/export/geonames-search.html), but it's also useful to look at the search results that you receive for filtering ideas. Usually, the information that tells you that a result is irrelevant to your query is information that you can put into a filter. That's how I found the "adminCode1" and "featureCode" parameters.

# %%
Q['country'] = 'US'
Q['adminCode1'] = 'MA' 
Q['featureCode'] = 'PPL' # These keys didn't exist until we set them to something! We can create keys this way.
Q
# Out:
# {'adminCode1': 'MA',
#  'country': 'US',
#  'featureCode': 'PPL',
#  'q': 'Somerville',
#  'username': 'cdc43339'}

# %%
R = requests.get(url,params=Q)

# %%
R.url
# Out:
# 'http://api.geonames.org/searchJSON?q=Somerville&username=cdc43339&country=US&adminCode1=MA&featureCode=PPL'

# %%
R.json()
# Out:
# {'geonames': [{'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4951257,
#    'lat': '42.3876',
#    'lng': '-71.0995',
#    'name': 'Somerville',
#    'population': 80318,
#    'toponymName': 'Somerville'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4955085,
#    'lat': '42.39593',
#    'lng': '-71.12255',
#    'name': 'West Somerville',
#    'population': 0,
#    'toponymName': 'West Somerville'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4952743,
#    'lat': '42.39676',
#    'lng': '-71.087',
#    'name': 'Ten Hills',
#    'population': 0,
#    'toponymName': 'Ten Hills'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4935509,
#    'lat': '42.38673',
#    'lng': '-71.0839',
#    'name': 'East Somerville',
#    'population': 0,
#    'toponymName': 'East Somerville'},
#   {'adminCode1': 'MA',
#    'adminCodes1': {'ISO3166_2': 'MA'},
#    'adminName1': 'Massachusetts',
#    'countryCode': 'US',
#    'countryId': '6252001',
#    'countryName': 'United States',
#    'fcl': 'P',
#    'fclName': 'city, village,...',
#    'fcode': 'PPL',
#    'fcodeName': 'populated place',
#    'geonameId': 4955986,
#    'lat': '42.39593',
#    'lng': '-71.09894',
#    'name': 'Winter Hill',
#    'population': 0,
#    'toponymName': 'Winter Hill'}],
#  'totalResultsCount': 5}

# %% [markdown]
# ## Try it out!
#
# Now it's your turn. Try limiting your search to a particular part of the state of Massachusetts! You can always look back at the [API Documentation](http://www.geonames.org/export/geonames-search.html) for ideas.
#
# *Hint: [this website](http://boundingbox.klokantech.com/) might be of assistance. I've found the DublinCore output to be pretty readable.*

# %%
Q
# Out:
# {'adminCode1': 'MA',
#  'country': 'US',
#  'featureCode': 'PPL',
#  'q': 'Somerville',
#  'username': 'cdc43339'}

# %% [markdown]
# ## Working with our results
#
# We can set up our results as their own object that we can work with. Don't worry, you're not re-requesting the data every time you work with the request object "R", the online request gets made once when the object is created, and from then on, the request object is just information about that request stored in memory.

# %%
result = R.json()

# %%
type(result)
# Out:
# dict

# %%
result['geonames'][0] # Here is the first response, since list slicing starts counting from 0
# Out:
# {'adminCode1': 'MA',
#  'adminCodes1': {'ISO3166_2': 'MA'},
#  'adminName1': 'Massachusetts',
#  'countryCode': 'US',
#  'countryId': '6252001',
#  'countryName': 'United States',
#  'fcl': 'P',
#  'fclName': 'city, village,...',
#  'fcode': 'PPL',
#  'fcodeName': 'populated place',
#  'geonameId': 4951257,
#  'lat': '42.3876',
#  'lng': '-71.0995',
#  'name': 'Somerville',
#  'population': 80318,
#  'toponymName': 'Somerville'}

# %%
print(result['geonames'][0]['lat'], result['geonames'][0]['lng']) # Prints the lat and the long from the first result

# %% [markdown]
# ## Making a function
#
# That's all well and good, but if we had to write all that code for every lat/long pair that we wanted to get, we wouldn't be saving ourselves any time. However, we can create a function to do our search for us, and return the information that we're interested in.
#
# If you're still pretty new to Python, you may not have made many functions, so we'll go over the basics.
#
# When you set up a function, you start with something like this:
#
# ```python
# def somefunction(argument1, argument2, argument3=None):
# ```
#
# This says "I'm making a function called `somefunction`, and when you run this function, you can specify some parameters that I'm going to calll `argument1`, `argument2`, and `argument3`. Also, you don't have to specify `argument3`. It'll default to `None` if you don't specify it."
#
# Within the context of your function, you can do whatever you want with those inputs. In our case, we're using them to make an API request. The code inside is up to you, the important thing is that you end with a `return` statement. That's what makes your function spit out something. In our case, we want the latitude and longitude back from our function.
#
# You'll notice that we're returning two values, separated by a comma, but not enclosed by anything. When you do that in a return statement, Python interprets that as "return a tuple", which is a kind of container, very similar to a list, but not set up to be modifiable. We can get away with using this very simple data container, so we'll use it.

# %%
def search_us_place(placename,state_abbrev):
    url = "http://api.geonames.org/searchJSON"
    Q = {
        'q':placename,
        'country':'US',
        'username':USERNAME,
        'adminCode1':state_abbrev
    }
    results = requests.get(url,params=Q).json()
    top_result = results['geonames'][0]
    return top_result['lat'], top_result['lng']

# %%
test = search_us_place('Worcester','MA')
print(type(test))
print(test)

# %% [markdown]
# ## Try it out!
#
# Try making your own function to get some data that is of interest to you. If you want an idea to implement, imagine that you have a lot of location names in English, and you want to get the Mandarin names. How would you write a function that returns those names from a search query in English?
#
# Don't forget to check the [documentation,](http://www.geonames.org/export/geonames-search.html) and you might have to do a bit of Googling.

# %%
def myfunc():
    return 0

# %% [markdown]
# ## Applying our function to a dataset
#
# Now that we have a function to give us lat/long pairs from a city name and state, we can actually apply it to a dataset. I've prepared a small dataset: a list of botanical gardens and arboretums in Massachusetts ([from Wikipedia](https://en.wikipedia.org/wiki/List_of_botanical_gardens_and_arboretums_in_Massachusetts)).
#
# The way I like to do that is with the Pandas module in Python. Pandas is a module that has a lot of tools for working with tabular data, and is a favorite among data scientists. We're using it today because it makes working with CSV files really really easy.

# %%
import pandas as pd

# %% [markdown]
# ### Don't panic...
#
# This cell is going to produce an error. Take a look at the error message and our csv file to see if you can figure out what the problem is. You can look ahead to the next cell for the fix, but that'd be cheating!

# %%
df = pd.read_csv('botanical_gardens.csv')
df.head()

# %%
df = pd.read_csv('botanical_gardens.csv',sep='\t') # Working file opener with separator as tabs
df.head()

# %% [markdown]
# ### Being nice to APIs
#
# A lot of APIs, especially smaller APIs, aren't built to withstand a bunch of users hammering away at them as fast as their processors will allow. APIs like some of Google's have explicit rate limits, some of which are quite high, because the back ends are so robust. For our purposes, we'll go nice and easy with a 1 second delay between requests.
#
# You'll also notice that there are some new print statements. If you're going to be running a function a whole bunch of times, it's good to get feedback on where it is in its loop, and so if things go wrong, you know where they went wrong.

# %%
import time

def search_us_place(placename,state_abbrev):
    url = "http://api.geonames.org/searchJSON"
    Q = {
        'q':placename,
        'country':'US',
        'username':USERNAME,
        'adminCode1':state_abbrev
    }
    print('making request for {}, {}'.format(placename,state_abbrev))
    R = requests.get(url,params=Q)
    print(R.url)
    results = R.json()
    top_result = results['geonames'][0]
    print('got result for {}, {}'.format(placename,state_abbrev))
    time.sleep(1)
    return top_result['lat'], top_result['lng']

# %%
search_us_place('Boston','MA') # Now we'll run this new function

# %% [markdown]
# ### Applying functions to our csv
#
# Another nice thing about pandas is how efficiently the library applies functions to dataframes. We want to apply our function to the spreadsheet. Since all of our data is in the same state, we can send `'MA'` as the state abbreviation every time.
#
# We can accomplish that with a lambda function, which is just an anonymous function to use in a place where you need a function, but you don't think you'll need to reuse that function. We're using it to apply a function with a consistent parameter, but you can use it for simpler things like adding a number or a prefix to a column.
#
# We're setting the results of that function to the variable `latLngs`.

# %%
latLngs = df.City.apply(lambda x: search_us_place(x,'MA'))

# %% [markdown]
# ### What is our output?
#
# If you look at our `latLngs` output, you'll notice that it's pretty similar to other columns in our existing dataframe. That's because it's the same sort of thing, except that our lat/longs are still tuples. We could have a column of tuples, but wouldn't it be nice to have two columns, one for latitude and one for longitude?

# %%
latLngs

# %%
df.City

# %% [markdown]
# ### Zip up the results
#
# You'll find a more detailed explanation of why this works at the bottom of this notebook, but for now, just know that this is a way to set multiple columns from output like what we have from applying our function.

# %%
df['lat'],df['lng'] = zip(*latLngs)

# %%
df.head()

# %% [markdown]
# ## Saving the results
#
# Saving a csv file is incredibly easy, you can do it with just a filename. However, it does add the index as an extra column of numbers, which we don't need in our dataset, so I'm choosing to omit that.

# %%
df.to_csv('botanical_gardens_with_location.csv',index=None)

# %% [markdown]
# ## Try it out!
#
# Using the function that you made earlier, add a new column (or columns!) to our dataframe, then save it with an appropriate filename.

# %%
# Put your code here, adding more cells as needed

# %% [markdown]
# # Data enriched!
#
# That's it, we've gone through the whole process of using an API to enrich data in python. To review, we:
#
# * Explored the API we wanted to use
# * Built a function to make a request we wanted
# * Imported our csv data
# * Ran our function on our dataset
# * Saved our outpu
#
# Whatever API you use to enrich a dataset, you can typically use some variation of this workflow. I recommend using a notebook like this one, especially for early explorations, so you can leave a record of your exploration process, and re-use portions of code elsewhere.

# %% [markdown]
# # Reverse the flow!
#
# We can also use APIs to add data from our datasets to a website, too.
#
# Here, we'll use the API for Omeka. Omeka is a content management system, like WordPress, but focused on making the collections of libraries, archives, and museums more easily accessible on the web. It's built around the concept of items, and focuses on describing those items, collecting them sensibly, and incorporating them into online narratives.
#
# The site we'll be using is the site that we use for testing our Omeka service here: http://testing.omeka-dev.fas.harvard.edu/
#
# You'll find documentation for the API here: http://omeka.readthedocs.io/en/latest/Reference/api/index.html
#
# Our goal for this portion will be to use the documentation and what we've already learned to create items in Omeka representing each of the places in our dataframe.
#
# Before we get started on that, we'll want to see how the API represents items, so we can copy that when creating new ones.

# %%
omeka_api_key = '' # We'll give you a key to use for the site

# %%
# We're not using the key yet, since we're just viewing public information
R = requests.get('http://demo.omeka.fas.harvard.edu/api/items/36')
demo_item = R.json()

# %%
demo_item

# %% [markdown]
# ## New function!
#
# Since making items isn't exactly intuitive, let's make a quick function to construct items from dictionaries. We're relying on some things specific to this site, namely the IDs of each element, and for a more general solution we'd want to do something more nuanced than hord coding those IDs into our workflow. For now, though, this is a workable solution

# %%
def make_item(element_texts):
    """
    Takes a dictionary with format {element_id:element_text, ...}
    """
    base_item = {
        'element_texts':[],
        'featured': False,
        'public': True,
    }
    for _id, text in element_texts.items():
        element = {
            'element': { 'id': int(_id) },
            'text': text,
            'html': True
        }
        base_item['element_texts'].append(element)
    return base_item

# %%
test = {
    50: 'A Test Item',
    41: "The description of the test item. It might be a bit longer, which is fine since it won't be used as a page title or anything."
}
test_item = make_item(test)
print(test_item)

# %% [markdown]
# ## POST new data
#
# Now that we have content to upload, let's take a look at how we'll do that. We're using a different method of sending data to the url, you'll notice. We're POSTing data, which usually means we're adding something new. We can still use our `params` argument, but our data is in our `json` argument.
#
# The `requests` module has this as a convenient parameter, so you don't have to turn your dictionary into a string to use it as a data payload. Since this is such a common task, `requests` has built it into this method call so we can just use the dictionary object we've created.
#
# We'll still get a response, but in this case, we'll get a representation of the item that we just created, as long as it was created successfully. We know this from the documentation, which tells us what response to expect from each kind of query we can send to the items API endpoint.

# %%
R = requests.post('http://demo.omeka.fas.harvard.edu/api/items',json=test_item, params={'key':omeka_api_key})

# %%
R.json()

# %% [markdown]
# ## Functions in functions
#
# We can make another function to take a dictionary that represents our item in a pretty convenient way and add that directly to Omeka. We're using the function that we made to create an item within this function, so we don't have to add that functionality to this function too. We might want to keep these functions separate, in case we want to use the `make_item` function on its own for some other purpose, like creating several items and then adding them all at once.
#
# The second function is designed to go from a single row from our spreadsheet directly to the creation of an Item in Omeka. You can change the items that you add by changing this function. In fact, I encourage you to do so, since we'll all be adding items, and it'll be hard to tell which ones are yours.

# %%
def add_item_to_omeka(element_texts):
    item = make_item(element_texts)
    R = requests.post('http://demo.omeka.fas.harvard.edu/api/items',json=item, params={'key':omeka_api_key})
    return R.json()

# %%
def row_to_omeka(row):
    title = row['Name']
    description = "Located in {}, MA ({},{})".format(row['City'],row['lat'],row['lng'])
    element_texts = {
        '50': title,
        '41': description,
        '39': 'Your name here!'
    }
    response = add_item_to_omeka(**element_texts)
    return response

# %%
df.apply(row_to_omeka,axis=1)

# %% [markdown]
# # Addendum: The zip() function
#
# In case you're curious, this is how that funky line we used to assign multiple columns worked:
#
# ```python
# df['lat'],df['lng'] = zip(*latLngs)
# ```

# %% [markdown]
# The `zip()` function returns what's called a "generator" object, which is a Python object that won't show you its contents, but rather contains instructions to quickly generate those contents on the fly. You'll find something similar with the `range()` function.

# %%
print(zip([1,2],[3,4],[5,6],[7,8]))

# %% [markdown]
# So, to look inside, we have to iterate through and print the contents. Notice that I'm providing these lists as individual arguments. Zip takes as many arguments as you care to give it, through the `*args` keyword in its function definition. This means that there will be a list `args` in the function that something happens to. In this case, we're taking the first value of each list, and making one tuple from those values, and taking the second value and making another list. This will work no matter how many items are in each list.

# %%
for z in zip([1,2],[3,4],[5,6],[7,8]):
    print(z)

# %% [markdown]
# You may be thinking "Great! I have a list of lists, I'll just put that in as my argument!"
#
# Let's see what happens when you do that:

# %%
test = [[1,2],[3,4],[5,6],[7,8]]
for z in zip(test):
    print(z)

# %% [markdown]
# That doesn't look like what we want. What we did in that line was to pass the whole list as a single argument, when what we wanted was to pass each list item as its own argument, like this:

# %%
for z in zip(test[0],test[1],test[2],test[3]):
    print(z)

# %% [markdown]
# However, that would be a lot of typing for a long list. Fortunately, we can prefix our list with `*`, to do just what we want, and pass our entire list directly to the function's `*args` keyword.

# %%
for z in zip(*test):
    print(z)

# %% [markdown]
# But how does that help our problem? Well, our collection of lat/long coordinates is iterable in the same way that a list is, so in this case we can use it in the same way. This next block is just a demonstration of that iterability.

# %%
for ll in latLngs:
    print(ll)

# %% [markdown]
# And now, we have all of the pieces together, so we can see that the output of our `zip()` function is in fact two tuples, each with one of our desired columns of data. Since they're each the same length as our dataframe (being derived from it), we can turn them into new columns just by setting the new columns equal to them.

# %%
for z in zip(*latLngs):
    print(z)
